# %% [markdown]
# ##for Analyzing the Starbucks data

# %%
#Type of ownership
    #Company Owned
    #Licensed
    #Franchised
    #Joint Venture
    #Success
    #Location densities 
#Success (use with Google API?)
#Location densities  use with Google API?)

# %%
# Dependencies
import pandas as pd
import requests
import json

# Google developer API key
from config import gkey

# %%
# Make a reference to the books.csv file path
csv_path = "Cleaned_Starbucks_Data/starbucks.csv"

# Import the books.csv file as a DataFrame
starbucks_df = pd.read_csv(csv_path, encoding="utf-8")
starbucks_df.head()
# Out:
#    Store Number                 Store Name       City State/Province Country  \
# 0   3513-125945    Safeway-Anchorage #1809  Anchorage             AK      US
# 1   74352-84449    Safeway-Anchorage #2628  Anchorage             AK      US
# 2  12449-152385  Safeway - Anchorage #1813  Anchorage             AK      US
# 3  24936-233524   100th & C St - Anchorage  Anchorage             AK      US
# 4    8973-85630       Old Seward & Diamond  Anchorage             AK      US
#
#     Postcode  Longitude  Latitude
# 0  995042300    -149.78     61.21
# 1  995073444    -149.84     61.14
# 2  995153596    -149.85     61.11
# 3      99515    -149.89     61.13
# 4  995152050    -149.86     61.14

# %%
starbucks_df['Zip Code'] = starbucks_df['Postcode'].where(starbucks_df['Postcode'].str.len() == 5, 
                                               starbucks_df['Postcode'].str[:5])
starbucks_df.head()
# Out:
#    Store Number                 Store Name       City State/Province Country  \
# 0   3513-125945    Safeway-Anchorage #1809  Anchorage             AK      US
# 1   74352-84449    Safeway-Anchorage #2628  Anchorage             AK      US
# 2  12449-152385  Safeway - Anchorage #1813  Anchorage             AK      US
# 3  24936-233524   100th & C St - Anchorage  Anchorage             AK      US
# 4    8973-85630       Old Seward & Diamond  Anchorage             AK      US
#
#     Postcode  Longitude  Latitude Zip Code
# 0  995042300    -149.78     61.21    99504
# 1  995073444    -149.84     61.14    99507
# 2  995153596    -149.85     61.11    99515
# 3      99515    -149.89     61.13    99515
# 4  995152050    -149.86     61.14    99515

# %%
#Type of ownership

# %%
#Success (use with Google API?)

# %%
#Location densities  use with Google API?)
